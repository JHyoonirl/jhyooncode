# %%
import ultralytics
import os
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.6  Python-3.10.14 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
# Setup complete  (20 CPUs, 31.8 GB RAM, 256.5/476.1 GB disk)

# %%
current_path = os.getcwd()
print(current_path)
# Out:
# c:\Users\IRL\OneDrive - pusan.ac.kr\바탕 화면\jhyooncode\Create_model

# %%
model = ultralytics.YOLO('yolov8m.pt')
yaml_path = current_path + '\Sulivan_train\data'
model.train(data=yaml_path+'\data.yaml', epochs=500, batch=40, imgsz=500)
# Out:
# Ultralytics YOLOv8.2.6  Python-3.10.14 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
# ...
