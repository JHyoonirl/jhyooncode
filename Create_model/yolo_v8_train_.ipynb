# %%
import ultralytics
import os
import torch
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.15  Python-3.10.14 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
# Setup complete  (20 CPUs, 31.8 GB RAM, 289.5/476.1 GB disk)

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="HFkCToeQS6j19qszUI3y")
project = rf.workspace("jhyoon-zf6gn").project("sulivan-model")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.15, to fix: `pip install ultralytics==8.0.196`

# %%
current_path = os.getcwd()
print(current_path)
print(torch.cuda.is_available())
# Out:
# c:\Users\IRL\OneDrive - pusan.ac.kr\바탕 화면\jhyooncode\Create_model
# True

# %%
model = ultralytics.YOLO('yolov8m.pt')
yaml_path = current_path + '\Sulivan-model-3'
model.train(data=yaml_path+'\data.yaml', epochs=200, batch=16, imgsz=640)
# Out:
# Ultralytics YOLOv8.2.15  Python-3.10.14 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
# ...
